# %% [markdown]
# ### Basic Checks

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('netflix_titles.csv')
print(df.shape)
df.head()
# Out:
# (8807, 12)
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8807 non-null   object
#  1   type          8807 non-null   object
#  2   title         8807 non-null   object
#  3   director      6173 non-null   object
#  4   cast          7982 non-null   object
#  5   country       7976 non-null   object
#  6   date_added    8797 non-null   object
#  7   release_year  8807 non-null   int64
#  8   rating        8803 non-null   object
#  9   duration      8804 non-null   object
#  10  listed_in     8807 non-null   object
#  11  description   8807 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 825.8+ KB

# %%
df.describe(include='object')
# Out:
#        show_id   type                 title       director  \
# count     8807   8807                  8807           6173
# unique    8807      2                  8807           4528
# top         s1  Movie  Dick Johnson Is Dead  Rajiv Chilaka
# freq         1   6131                     1             19
#
#                       cast        country       date_added rating  duration  \
# count                 7982           7976             8797   8803      8804
# unique                7692            748             1767     17       220
# top     David Attenborough  United States  January 1, 2020  TV-MA  1 Season
# freq                    19           2818              109   3207      1793
#
#                            listed_in  \
# count                           8807
# unique                           514
# top     Dramas, International Movies
# freq                             362
#
#                                               description
# ...

# %% [markdown]
# ### Exploratory Data Analysis

# %%
df.release_year.value_counts()
# Out:
# 2018    1147
# 2017    1032
# 2019    1030
# 2020     953
# 2016     902
#         ...
# 1959       1
# 1925       1
# 1961       1
# 1947       1
# 1966       1
# Name: release_year, Length: 74, dtype: int64

# %%
plt.figure(figsize=(8,6))
sns.countplot(y=df.release_year,order=df.release_year.value_counts().index[0:15],palette="cubehelix")
# order=netflix_movies['release_year'].value_counts().index[0:15]
# Out:
# <AxesSubplot: xlabel='count', ylabel='release_year'>

# %% [markdown]
# In year 2018 most of the shows are released

# %% [markdown]
# ##### Top 10 countries with more release

# %%
# df.loc[(]
temp=df.country.value_counts()
temp.index
test_10=df[df.country.isin(temp[temp>20].index)]
test_10.country.value_counts()
# Out:
# United States                    2818
# India                             972
# United Kingdom                    419
# Japan                             245
# South Korea                       199
# Canada                            181
# Spain                             145
# France                            124
# Mexico                            110
# Egypt                             106
# Turkey                            105
# Nigeria                            95
# Australia                          87
# Taiwan                             81
# Indonesia                          79
# Brazil                             77
# United Kingdom, United States      75
# Philippines                        75
# United States, Canada              73
# Germany                            67
# China                              66
# Thailand                           61
# Argentina                          56
# Hong Kong                          53
# United States, United Kingdom      47
# ...

# %%
plt.figure(figsize=(6,4))
sns.countplot(y=df.country,order=df.country.value_counts().index[0:10])
# Out:
# <AxesSubplot: xlabel='count', ylabel='country'>

# %% [markdown]
# ##### USA country is having more release followed by India and United Kingdom

# %%
director=df.groupby('director')

# %%
director.get_group('Rajiv Chilaka')
# Out:
#      show_id   type                                              title  \
# 406     s407  Movie                       Chhota Bheem - Neeli Pahaadi
# 407     s408  Movie                              Chhota Bheem & Ganesh
# 408     s409  Movie                 Chhota Bheem & Krishna: Mayanagari
# 409     s410  Movie  Chhota Bheem & Krishna: Pataliputra- City of t...
# 410     s411  Movie                 Chhota Bheem And The Broken Amulet
# 411     s412  Movie             Chhota Bheem And The Crown of Valhalla
# 412     s413  Movie               Chhota Bheem and the Incan Adventure
# 413     s414  Movie                Chhota Bheem and The ShiNobi Secret
# 414     s415  Movie                           Chhota Bheem Aur Hanuman
# 415     s416  Movie                           Chhota Bheem aur Krishna
# 416     s417  Movie                Chhota Bheem aur Krishna vs Zimbara
# 419     s420  Movie                      Chhota Bheem: Bheem vs Aliens
# ...

# %% [markdown]
# Director "Rajiv Chilaka" is having more record in datasets and all of them are series of movies names "Chhota Bheem"

# %%
df.listed_in.value_counts()
# Out:
# Dramas, International Movies                          362
# Documentaries                                         359
# Stand-Up Comedy                                       334
# Comedies, Dramas, International Movies                274
# Dramas, Independent Movies, International Movies      252
#                                                      ...
# Kids' TV, TV Action & Adventure, TV Dramas              1
# TV Comedies, TV Dramas, TV Horror                       1
# Children & Family Movies, Comedies, LGBTQ Movies        1
# Kids' TV, Spanish-Language TV Shows, Teen TV Shows      1
# Cult Movies, Dramas, Thrillers                          1
# Name: listed_in, Length: 514, dtype: int64

# %% [markdown]
# #####

# %% [markdown]
# ##### Top 10 Generes for movies

# %%
df.type.value_counts()
# Out:
# Movie      6131
# TV Show    2676
# Name: type, dtype: int64

# %%
movies=df[df.type=='Movie']
shows=df[df.type=='TV Show']

# %%
sns.countplot(y=movies.listed_in, order=movies.listed_in.value_counts().index[0:10],palette="cubehelix")
# Out:
# <AxesSubplot: xlabel='count', ylabel='listed_in'>

# %% [markdown]
# #

# %% [markdown]
# ##### Top 10 generes for TV Shows

# %%
sns.countplot(y=shows.listed_in, order=shows.listed_in.value_counts().index[0:10],palette="cubehelix")
# Out:
# <AxesSubplot: xlabel='count', ylabel='listed_in'>

# %% [markdown]
# #

# %%
df.rating.value_counts()
# Out:
# TV-MA       3207
# TV-14       2160
# TV-PG        863
# R            799
# PG-13        490
# TV-Y7        334
# TV-Y         307
# PG           287
# TV-G         220
# NR            80
# G             41
# TV-Y7-FV       6
# NC-17          3
# UR             3
# 74 min         1
# 84 min         1
# 66 min         1
# Name: rating, dtype: int64

# %%
sns.countplot(y=df.rating,order=df.rating.value_counts().index,palette="cubehelix")
# Out:
# <AxesSubplot: xlabel='count', ylabel='rating'>

# %% [markdown]
# ###### 36% with TV-MA rating which is for mature audience.
# ###### 24% with TV-14 rating which is for audience having age more than 14

# %%
df[df.rating=='74 min']
# Out:
#      show_id   type            title    director        cast        country  \
# 5541   s5542  Movie  Louis C.K. 2017  Louis C.K.  Louis C.K.  United States
#
#          date_added  release_year  rating duration listed_in  \
# 5541  April 4, 2017          2017  74 min      NaN    Movies
#
#                                             description
# 5541  Louis C.K. muses on religion, eternal love, gi...

# %%
df[df.rating=='84 min']
# Out:
#      show_id   type                  title    director        cast  \
# 5794   s5795  Movie  Louis C.K.: Hilarious  Louis C.K.  Louis C.K.
#
#             country          date_added  release_year  rating duration  \
# 5794  United States  September 16, 2016          2010  84 min      NaN
#
#      listed_in                                        description
# 5794    Movies  Emmy-winning comedy writer Louis C.K. brings h...

# %%
df[df.rating=='66 min']
# Out:
#      show_id   type                                 title    director  \
# 5813   s5814  Movie  Louis C.K.: Live at the Comedy Store  Louis C.K.
#
#             cast        country       date_added  release_year  rating  \
# 5813  Louis C.K.  United States  August 15, 2016          2015  66 min
#
#      duration listed_in                                        description
# 5813      NaN    Movies  The comic puts his trademark hilarious/thought...

# %% [markdown]
# these seems wrong imputation of values we can drop them

# %%
df.duration.unique()
# Out:
# array(['90 min', '2 Seasons', '1 Season', '91 min', '125 min',
#        '9 Seasons', '104 min', '127 min', '4 Seasons', '67 min', '94 min',
#        '5 Seasons', '161 min', '61 min', '166 min', '147 min', '103 min',
#        '97 min', '106 min', '111 min', '3 Seasons', '110 min', '105 min',
#        '96 min', '124 min', '116 min', '98 min', '23 min', '115 min',
#        '122 min', '99 min', '88 min', '100 min', '6 Seasons', '102 min',
#        '93 min', '95 min', '85 min', '83 min', '113 min', '13 min',
#        '182 min', '48 min', '145 min', '87 min', '92 min', '80 min',
#        '117 min', '128 min', '119 min', '143 min', '114 min', '118 min',
#        '108 min', '63 min', '121 min', '142 min', '154 min', '120 min',
#        '82 min', '109 min', '101 min', '86 min', '229 min', '76 min',
#        '89 min', '156 min', '112 min', '107 min', '129 min', '135 min',
#        '136 min', '165 min', '150 min', '133 min', '70 min', '84 min',
# ...

# %%
df['mins']=df.duration.str.split(' ').str[0]
df.mins=pd.to_numeric(df.mins)

# %%
movies.dropna(subset=['duration'], inplace=True)
# Out:
# C:\Users\Datamites\AppData\Local\Temp\ipykernel_9512\148623466.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   movies.dropna(subset=['duration'], inplace=True)

# %%
movies['mins2']=movies['duration'].str.replace(' min','')
movies['mins2']=movies['mins2'].astype(str).astype(int)
movies['mins2']
# Out:
# C:\Users\Datamites\AppData\Local\Temp\ipykernel_9512\1370815327.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   movies['mins2']=movies['duration'].str.replace(' min','')
# C:\Users\Datamites\AppData\Local\Temp\ipykernel_9512\1370815327.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   movies['mins2']=movies['mins2'].astype(str).astype(int)
# 0        90
# 6        91
# 7       125
# 9       104
# 12      127
#        ...
# 8801     96
# 8802    158
# 8804     88
# 8805     88
# ...

# %%
sns.histplot(movies.mins2)
# Out:
# <AxesSubplot: xlabel='mins2', ylabel='Count'>

# %% [markdown]
# ##### In dataset most of the shows are having duration of 100 mins

# %%
df.describe()
# Out:
#        release_year         mins
# count   8807.000000  8804.000000
# mean    2014.180198    69.846888
# std        8.819312    50.814828
# min     1925.000000     1.000000
# 25%     2013.000000     2.000000
# 50%     2017.000000    88.000000
# 75%     2019.000000   106.000000
# max     2021.000000   312.000000

# %%
df[df.mins==312]
# Out:
#      show_id   type                       title director  \
# 4253   s4254  Movie  Black Mirror: Bandersnatch      NaN
#
#                                                    cast        country  \
# 4253  Fionn Whitehead, Will Poulter, Craig Parkinson...  United States
#
#              date_added  release_year rating duration  \
# 4253  December 28, 2018          2018  TV-MA  312 min
#
#                                            listed_in  \
# 4253  Dramas, International Movies, Sci-Fi & Fantasy
#
#                                             description   mins
# 4253  In 1984, a young programmer begins to question...  312.0

# %% [markdown]
# ###### 312 mins long movie is in dataset with title: 'Black Mirror: Bandersnatch'

# %%
shows.duration.unique()
# Out:
# array(['2 Seasons', '1 Season', '9 Seasons', '4 Seasons', '5 Seasons',
#        '3 Seasons', '6 Seasons', '7 Seasons', '10 Seasons', '8 Seasons',
#        '17 Seasons', '13 Seasons', '15 Seasons', '12 Seasons',
#        '11 Seasons'], dtype=object)

# %%
shows['no_of_seasons']=shows.duration.str.split(' ').str[0]
shows.no_of_seasons=shows.no_of_seasons.astype(str).astype(int)
shows.no_of_seasons
# Out:
# C:\Users\Datamites\AppData\Local\Temp\ipykernel_9512\998304790.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   shows['no_of_seasons']=shows.duration.str.split(' ').str[0]
# C:\Users\Datamites\AppData\Local\Temp\ipykernel_9512\998304790.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   shows.no_of_seasons=shows.no_of_seasons.astype(str).astype(int)
# 1       2
# 2       1
# 3       1
# 4       2
# 5       1
#        ..
# 8795    2
# 8796    2
# 8797    3
# 8800    1
# 8803    2
# ...

# %%
sns.histplot(shows.no_of_seasons)
# Out:
# <AxesSubplot: xlabel='no_of_seasons', ylabel='Count'>

# %%
top_shows=shows[['title','no_of_seasons']].sort_values(by='no_of_seasons', ascending=False)[0:10]

# %%
sns.barplot(x=top_shows.no_of_seasons,y=top_shows.title,palette="cubehelix")
# Out:
# <AxesSubplot: xlabel='no_of_seasons', ylabel='title'>

# %% [markdown]
# ###### Greys anatomy, supernatural and NCIS are top shows with Seasons with more than 14

# %% [markdown]
# #

# %%
df
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
# ...

# %%
df.type.value_counts()
# Out:
# Movie      6131
# TV Show    2676
# Name: type, dtype: int64

# %% [markdown]
# ##### in dataset there are 2.3 times more Movies than TV shows

# %% [markdown]
# #

# %%
df.description.str.len().max()
# Out:
# 248

# %%
df.description.str.len().min()
# Out:
# 61

# %%
df[df.description.str.len()==248]
# Out:
#      show_id   type            title             director  \
# 4797   s4798  Movie  Namastey London  Vipul Amrutlal Shah
# 4948   s4949  Movie            Billu         Priyadarshan
#
#                                                    cast country  \
# 4797  Akshay Kumar, Katrina Kaif, Rishi Kapoor, Upen...   India
# 4948  Irrfan Khan, Shah Rukh Khan, Lara Dutta, Rajpa...   India
#
#          date_added  release_year rating duration  \
# 4797   July 1, 2018          2007  TV-14  130 min
# 4948  April 1, 2018          2009  TV-PG  132 min
#
#                                    listed_in  \
# 4797  Comedies, Dramas, International Movies
# 4948            Dramas, International Movies
#
#                                             description   mins
# 4797  To her Indian parents' dismay, London-born Jas...  130.0
# 4948  An Indian village is abuzz with news that a ma...  132.0

# %%
df[df.description.str.len()==61]
# Out:
#      show_id   type              title     director         cast  \
# 3007   s3008  Movie  WHAT DID JACK DO?  David Lynch  David Lynch
#
#             country        date_added  release_year rating duration  \
# 3007  United States  January 20, 2020          2020  TV-14   17 min
#
#                        listed_in  \
# 3007  Dramas, Independent Movies
#
#                                             description  mins
# 3007  A detective interrogates a monkey who is suspe...  17.0

# %%
pd.set_option('display.max_colwidth',None)
df[df.description.str.len()==248].description
# Out:
# 4797    To her Indian parents' dismay, London-born Jasmeet "Jazz" Malhotra longs for everything Western, including her British boyfriend. On a family trip to India, her father arranges Jazz's nuptials to Arjun Ballu Singh, who's smitten with his new bride.
# 4948    An Indian village is abuzz with news that a major movie star is coming to town – even more so because the town barber went to school with him. But as the day of the actor's visit approaches, the humble barber begins to worry he won't be recognized.
# Name: description, dtype: object

# %%
df[df.description.str.len()==61].description
# Out:
# 3007    A detective interrogates a monkey who is suspected of murder.
# Name: description, dtype: object

# %% [markdown]
# #

# %% [markdown]
# #### Word Cloud

# %%
! pip install wordcloud
# Out:
# ...
#      -------------------------------------- 153.1/153.1 kB 1.0 MB/s eta 0:00:00
# ...
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\datamites\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\datamites\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\datamites\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\datamites\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\datamites\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\datamites\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\datamites\anaconda3\lib\site-packages)

# %%
from collections import Counter

genres=list(df['listed_in'])
gen=[]

for i in genres:
    i=list(i.split(','))
    for j in i:
        gen.append(j.replace(' ',""))
g=Counter(gen)

# %%
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator
from PIL import Image

text = list(set(gen))
plt.rcParams['figure.figsize'] = (13, 13)

wordcloud = WordCloud(max_words=1000000,background_color="black").generate(str(text))

plt.imshow(wordcloud,interpolation="bilinear")
plt.axis("off")
plt.show()

# %%
import re
def clean(tx):
    tx=re.sub('[^A-Za-z0-9 ]', ' ',tx)
    tx=re.sub('\d+',' ',tx)
    tx=re.sub("\s\s+",' ',tx)
    tx=tx.lower()
    return tx
df['clean_des']=df.description.apply(lambda x:clean(x))
df.clean_des
# Out:
# 0       as her father nears the end of his life filmma...
# 1       after crossing paths at a party a cape town te...
# 2       to protect his family from a powerful drug lor...
# 3       feuds flirtations and toilet talk go down amon...
# 4       in a city of coaching centers known to train i...
#                               ...
# 8802    a political cartoonist a crime reporter and a ...
# 8803    while living alone in a spooky town a young gi...
# 8804    looking to survive in a world taken over by zo...
# 8805    dragged from civilian life a former superhero ...
# 8806    a scrappy but poor boy worms his way into a ty...
# Name: clean_des, Length: 8807, dtype: object

# %%
clean(' 54654 As her father nears the end of his life filmma 2121')
# Out:
# ' As her father nears the end of his life filmma '

# %% [markdown]
# #

# %% [markdown]
# ### Recommendations System

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
tfidf=TfidfVectorizer(stop_words='english')
features=tfidf.fit_transform(df.clean_des)

# %%
features.shape
# Out:
# (8807, 18621)

# %%
tfidf.get_feature_names()
# Out:
# c:\Users\Datamites\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   warnings.warn(msg, category=FutureWarning)
# ['aaliya',
#  'aamir',
#  'aang',
#  'aardman',
#  'aaron',
#  'abad',
#  'abagnale',
#  'abah',
#  'abandon',
#  'abandoned',
#  'abandoning',
#  'abandonment',
#  'abandons',
#  'abargil',
#  'abatutu',
#  'abbey',
#  'abbie',
#  'abbott',
#  'abby',
#  'abdel',
#  'abdelmoneim',
#  'abduct',
#  'abducted',
#  'abductee',
#  'abducting',
#  'abduction',
#  'abductions',
#  'abductors',
#  'abducts',
#  'abdullah',
#  'abdulrahman',
#  'abdus',
#  'abe',
#  'abel',
#  'abhay',
#  'abiding',
#  'abigail',
#  'abilene',
#  'abilities',
#  'ability',
#  'abla',
#  'able',
#  'abnormal',
#  'aboard',
#  'abolish',
#  'abominable',
#  'abortion',
#  'abortions',
#  'abound',
#  'aboveground',
# ...

# %%
# Import linear_kernel
from sklearn.metrics.pairwise import linear_kernel

# Compute the cosine similarity matrix
cosine_sim = linear_kernel(features, features)
indices = pd.Series(df.index, index=df.title).drop_duplicates()
def get_recommendations(title, cosine_sim=cosine_sim):
    idx = indices[title]

    # Get the pairwsie similarity scores of all movies with that movie
    sim_scores = list(enumerate(cosine_sim[idx]))

    # Sort the movies based on the similarity scores
    sim_scores = sorted(sim_scores, key=lambda x: x[1], reverse=True)

    # Get the scores of the 10 most similar movies
    sim_scores = sim_scores[1:11]

    # Get the movie indices
    movie_indices = [i[0] for i in sim_scores]

    # Return the top 10 most similar movies
    return df.title.iloc[movie_indices]

# %%
get_recommendations('Peaky Blinders')
# Out:
# 7683                    Our Godfather
# 7140    Jonathan Strange & Mr Norrell
# 2646                   My Stupid Boss
# 8293                         The Fear
# 3133                              Don
# 7785                Power Rangers Zeo
# 8539                       The Tudors
# 8467                       The Prison
# 1510                    The Con Is On
# 1964             High & Low The Movie
# Name: title, dtype: object
